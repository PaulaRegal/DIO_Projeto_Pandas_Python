# %% [markdown]
# # E quando o nosso código demora muito? Será que travou? Quanto tempo vai demorar?
#
# ### Biblioteca/Módulo tqdm
#
# - Vamos importar os arquivos csv da Empresa Contoso e tratar como fizemos ao longo desse módulo

# %%
import pandas as pd
#importando os arquivos
vendas_df = pd.read_csv(r'Contoso - Vendas  - 2017.csv', sep=';')
produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';')
lojas_df = pd.read_csv(r'Contoso - Lojas.csv', sep=';')
clientes_df = pd.read_csv(r'Contoso - Clientes.csv', sep=';')

#limpando apenas as colunas que queremos
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

#mesclando e renomeando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente').rename(columns={'E-mail': 'E-mail do Cliente'})
display(vendas_df)
# Out:
#         Unnamed: 0  Numero da Venda Data da Venda Data do Envio  ID Canal  \
# 0                0                1    01/01/2017    02/01/2017         1
# 1                1           880458    23/11/2017    23/11/2017         0
# 2                3            18610    08/01/2017    10/01/2017         2
# 3                8           180875    16/03/2017    16/03/2017         0
# 4                2           191019    20/03/2017    21/03/2017         1
# ...            ...              ...           ...           ...       ...
# 980637      980620           150948    03/03/2017    03/03/2017         0
# 980638      980619           414804    04/06/2017    07/06/2017         3
# 980639      980621           860842    16/11/2017    17/11/2017         1
# 980640      980641           903958    02/12/2017    02/12/2017         0
# 980641      980632           183653    17/03/2017    19/03/2017         2
#
#         ID Loja  ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 0            86         981            2        6825                   9
# 1           306         235           10        6825                   8
# 2           200         448            2        6825                  48
# 3           268         975            6        6825                   4
# 4           172         376            2        6825                   9
# ...         ...         ...          ...         ...                 ...
# 980637       81         486            2       38931                   4
# 980638       81         895            1       39074                   5
# 980639      158         759            4       38701                   6
# 980640      222        1435           10         815                   8
# 980641       85        1071            2       39118                   9
#
#         Quantidade Devolvida  \
# 0                          1
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ...                      ...
# 980637                     0
# 980638                     0
# 980639                     1
# 980640                     0
# 980641                     0
#
#                                         Nome do Produto_x  \
# 0              A. Datum Advanced Digital Camera M300 Pink
# 1       Litware Home Theater System 7.1 Channel M710 B...
# 2                          WWI Desktop PC1.80 E1801 Black
# 3         A. Datum Ultra Compact Digital Camera M190 Pink
# 4                   Adventure Works Laptop12 M1201 Silver
# ...                                                   ...
# 980637                         Proseware CRT19 E201 White
# 980638                             SV Keyboard E90 Silver
# 980639         Contoso 90W AC/DC Power Adapter E300 Black
# 980640  The Phone Company Touch Screen Phones SAW/On-w...
# 980641                  A. Datum SLR Camera 35" M358 Blue
#
#                      Nome da Loja_x              E-mail do Cliente  \
# 0              Loja Contoso Austin          rbrumfieldmy@ameblo.jp
# 1       Loja Contoso Europe Online          rbrumfieldmy@ameblo.jp
# 2             Loja Contoso Catalog          rbrumfieldmy@ameblo.jp
# 3          Loja Contoso Tokyo No.2          rbrumfieldmy@ameblo.jp
# 4            Loja Contoso Hartford          rbrumfieldmy@ameblo.jp
# ...                             ...                            ...
# 980637        Loja Contoso Bacliff   jackson48@adventure-works.com
# 980638        Loja Contoso Bacliff     jesse32@adventure-works.com
# 980639      Loja Contoso Haverhill       ana20@adventure-works.com
# 980640           Loja Contoso Roma        ekorneevmm@instagram.com
# 980641         Loja Contoso Spring       mary9@adventure-works.com
#
#                                         Nome do Produto_y  \
# 0              A. Datum Advanced Digital Camera M300 Pink
# 1       Litware Home Theater System 7.1 Channel M710 B...
# 2                          WWI Desktop PC1.80 E1801 Black
# 3         A. Datum Ultra Compact Digital Camera M190 Pink
# 4                   Adventure Works Laptop12 M1201 Silver
# ...                                                   ...
# 980637                         Proseware CRT19 E201 White
# 980638                             SV Keyboard E90 Silver
# 980639         Contoso 90W AC/DC Power Adapter E300 Black
# 980640  The Phone Company Touch Screen Phones SAW/On-w...
# 980641                  A. Datum SLR Camera 35" M358 Blue
#
#                      Nome da Loja_y              E-mail do Cliente
# 0              Loja Contoso Austin          rbrumfieldmy@ameblo.jp
# 1       Loja Contoso Europe Online          rbrumfieldmy@ameblo.jp
# 2             Loja Contoso Catalog          rbrumfieldmy@ameblo.jp
# 3          Loja Contoso Tokyo No.2          rbrumfieldmy@ameblo.jp
# 4            Loja Contoso Hartford          rbrumfieldmy@ameblo.jp
# ...                             ...                            ...
# 980637        Loja Contoso Bacliff   jackson48@adventure-works.com
# 980638        Loja Contoso Bacliff     jesse32@adventure-works.com
# 980639      Loja Contoso Haverhill       ana20@adventure-works.com
# 980640           Loja Contoso Roma        ekorneevmm@instagram.com
# 980641         Loja Contoso Spring       mary9@adventure-works.com
#
# [980642 rows x 17 columns]

# %% [markdown]
# ### Agora, imagina que a Loja Contoso Roma (ID 222), para tentar burlar o sistema de metas, diminuiu 1 da quantidade devolvida de todas as vendas que ela teve. Descobrindo isso, precisamos ajeitar a base
#
# - Farei com um for, principalmente por motivos didáticos, mas teríamos outras formas de fazer isso também.

# %%
#barra de progresso, inicia ela numa variavel e dentro do for vc da .update():

from tqdm import tqdm #biblioteca para ter a barra de progresso

pbar = tqdm(total=len(vendas_df['ID Loja']), position=0, leave=True) 
#barra de progresso para fica em uma linha só preciso colocar position=0, leave=True

for i, id_loja in enumerate(vendas_df['ID Loja']):
    pbar.update() #colocar para atualizar a cada iteração
    if id_loja == 222:
        vendas_df.loc[i, 'Quantidade Devolvida'] += 1
        
display(vendas_df)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 980642/980642 [03:55<00:00, 4164.39it/s]
#  99%|█████████████████████████████████████████████████████████████████████▌| 974625/980642 [00:15<00:00, 148939.10it/s]
#         Unnamed: 0  Numero da Venda Data da Venda Data do Envio  ID Canal  \
# 0                0                1    01/01/2017    02/01/2017         1
# 1                1           880458    23/11/2017    23/11/2017         0
# 2                3            18610    08/01/2017    10/01/2017         2
# 3                8           180875    16/03/2017    16/03/2017         0
# 4                2           191019    20/03/2017    21/03/2017         1
# ...            ...              ...           ...           ...       ...
# 980637      980620           150948    03/03/2017    03/03/2017         0
# 980638      980619           414804    04/06/2017    07/06/2017         3
# 980639      980621           860842    16/11/2017    17/11/2017         1
# 980640      980641           903958    02/12/2017    02/12/2017         0
# 980641      980632           183653    17/03/2017    19/03/2017         2
#
#         ID Loja  ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 0            86         981            2        6825                   9
# 1           306         235           10        6825                   8
# 2           200         448            2        6825                  48
# 3           268         975            6        6825                   4
# 4           172         376            2        6825                   9
# ...         ...         ...          ...         ...                 ...
# 980637       81         486            2       38931                   4
# 980638       81         895            1       39074                   5
# 980639      158         759            4       38701                   6
# 980640      222        1435           10         815                   8
# 980641       85        1071            2       39118                   9
#
#         Quantidade Devolvida  \
# 0                          1
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ...                      ...
# 980637                     0
# 980638                     0
# 980639                     1
# 980640                     2
# 980641                     0
#
#                                         Nome do Produto_x  \
# 0              A. Datum Advanced Digital Camera M300 Pink
# 1       Litware Home Theater System 7.1 Channel M710 B...
# 2                          WWI Desktop PC1.80 E1801 Black
# 3         A. Datum Ultra Compact Digital Camera M190 Pink
# 4                   Adventure Works Laptop12 M1201 Silver
# ...                                                   ...
# 980637                         Proseware CRT19 E201 White
# 980638                             SV Keyboard E90 Silver
# 980639         Contoso 90W AC/DC Power Adapter E300 Black
# 980640  The Phone Company Touch Screen Phones SAW/On-w...
# 980641                  A. Datum SLR Camera 35" M358 Blue
#
#                      Nome da Loja_x              E-mail do Cliente  \
# 0              Loja Contoso Austin          rbrumfieldmy@ameblo.jp
# 1       Loja Contoso Europe Online          rbrumfieldmy@ameblo.jp
# 2             Loja Contoso Catalog          rbrumfieldmy@ameblo.jp
# 3          Loja Contoso Tokyo No.2          rbrumfieldmy@ameblo.jp
# 4            Loja Contoso Hartford          rbrumfieldmy@ameblo.jp
# ...                             ...                            ...
# 980637        Loja Contoso Bacliff   jackson48@adventure-works.com
# 980638        Loja Contoso Bacliff     jesse32@adventure-works.com
# 980639      Loja Contoso Haverhill       ana20@adventure-works.com
# 980640           Loja Contoso Roma        ekorneevmm@instagram.com
# 980641         Loja Contoso Spring       mary9@adventure-works.com
#
#                                         Nome do Produto_y  \
# 0              A. Datum Advanced Digital Camera M300 Pink
# 1       Litware Home Theater System 7.1 Channel M710 B...
# 2                          WWI Desktop PC1.80 E1801 Black
# 3         A. Datum Ultra Compact Digital Camera M190 Pink
# 4                   Adventure Works Laptop12 M1201 Silver
# ...                                                   ...
# 980637                         Proseware CRT19 E201 White
# 980638                             SV Keyboard E90 Silver
# 980639         Contoso 90W AC/DC Power Adapter E300 Black
# 980640  The Phone Company Touch Screen Phones SAW/On-w...
# 980641                  A. Datum SLR Camera 35" M358 Blue
#
#                      Nome da Loja_y              E-mail do Cliente
# 0              Loja Contoso Austin          rbrumfieldmy@ameblo.jp
# 1       Loja Contoso Europe Online          rbrumfieldmy@ameblo.jp
# 2             Loja Contoso Catalog          rbrumfieldmy@ameblo.jp
# 3          Loja Contoso Tokyo No.2          rbrumfieldmy@ameblo.jp
# 4            Loja Contoso Hartford          rbrumfieldmy@ameblo.jp
# ...                             ...                            ...
# 980637        Loja Contoso Bacliff   jackson48@adventure-works.com
# 980638        Loja Contoso Bacliff     jesse32@adventure-works.com
# 980639      Loja Contoso Haverhill       ana20@adventure-works.com
# 980640           Loja Contoso Roma        ekorneevmm@instagram.com
# 980641         Loja Contoso Spring       mary9@adventure-works.com
#
# [980642 rows x 17 columns]
# 100%|██████████████████████████████████████████████████████████████████████| 980642/980642 [00:30<00:00, 148939.10it/s]
